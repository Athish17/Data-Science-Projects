# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import os

from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/d2/11/ebc51ff21ebc1a48b040859b0062bff4aa297c6cf26b1aa08a2c0ce22668/wordcloud-1.6.0-cp35-cp35m-win_amd64.whl (153kB)
# Requirement already satisfied (use --upgrade to upgrade): pillow in c:\users\admin\anaconda3\lib\site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.6.1 in c:\users\admin\anaconda3\lib\site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): matplotlib in c:\users\admin\anaconda3\lib\site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pytz in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): cycler in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pyparsing!=2.0.4,!=2.1.2,>=1.5.6 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil->matplotlib->wordcloud)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.6.0
# You are using pip version 8.1.2, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
os.chdir("C:\\Users\\admin\\Documents")

# %%
data = pd.read_csv("most_backed.csv")

# %%
data.head(3)
# Out:
#    Unnamed: 0  amt.pledged                                              blurb  \
# 0           0    8782571.0  \nThis is a card game for people who are into ...
# 1           1    6465690.0  \nAn unusually addicting, high-quality desk to...
# 2           2    5408916.0  \nBring Reading Rainbow’s library of interacti...
#
#                                by        category currency       goal  \
# 0                        Elan Lee  Tabletop Games      usd    10000.0
# 1      Matthew and Mark McLachlan  Product Design      usd    15000.0
# 2  LeVar Burton & Reading Rainbow             Web      usd  1000000.0
#
#           location  num.backers  \
# 0  Los Angeles, CA       219382
# 1       Denver, CO       154926
# 2  Los Angeles, CA       105857
#
#                                     num.backers.tier  \
# 0                            [15505, 202934, 200, 5]
# 1  [788, 250, 43073, 21796, 41727, 21627, 12215, ...
# 2  [19639, 14343, 9136, 2259, 5666, 24512, 4957, ...
#
#                                          pledge.tier  \
# 0                         [20.0, 35.0, 100.0, 500.0]
# 1  [1.0, 14.0, 19.0, 19.0, 35.0, 35.0, 79.0, 79.0...
# 2  [5.0, 10.0, 25.0, 30.0, 35.0, 50.0, 75.0, 100....
#
#                                                title  \
# 0                                  Exploding Kittens
# 1                      Fidget Cube: A Vinyl Desk Toy
# 2  Bring Reading Rainbow Back for Every Child, Ev...
#
#                                                  url
# 0                /projects/elanlee/exploding-kittens
# 1   /projects/antsylabs/fidget-cube-a-vinyl-desk-toy
# 2  /projects/readingrainbow/bring-reading-rainbow...

# %%
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(data['title']))

# %%
wordcloud

# %%
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000005ADE9784A8>
