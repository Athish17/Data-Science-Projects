# %%
def function(x):
    return 5+x
function(6)
# Out:
# 11

# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Documents'

# %%
df = pd.read_csv("CLI data.csv")

# %%
df
# Out:
#      Rank                                   City  CostofLivingIndex  \
# 0       1                    Zurich, Switzerland             149.53
# 1       2                      Hamilton, Bermuda             148.13
# 2       3                       Zug, Switzerland             142.54
# 3       4                    Geneva, Switzerland             142.12
# 4       5                     Basel, Switzerland             142.02
# 5       6                      Bern, Switzerland             135.51
# 6       7                  Lausanne, Switzerland             131.38
# 7       8                     Reykjavik, Iceland             130.73
# 8       9                    Lugano, Switzerland             124.39
# 9      10                      Stavanger, Norway             116.98
# 10     11                      Trondheim, Norway             116.02
# 11     12                           Oslo, Norway             114.78
# 12     13                         Bergen, Norway             112.66
# ...

# %%
df.head()
# Out:
#    Rank                 City  CostofLivingIndex  RentIndex  GroceriesIndex  \
# 0     1  Zurich, Switzerland             149.53      66.76          163.71
# 1     2    Hamilton, Bermuda             148.13     117.80          145.20
# 2     3     Zug, Switzerland             142.54      67.39          148.36
# 3     4  Geneva, Switzerland             142.12      70.25          147.13
# 4     5   Basel, Switzerland             142.02      51.54          149.54
#
#    RestaurantPriceIndex  LocalPurchasingPowerIndex
# 0                140.58                     126.30
# 1                152.54                      93.42
# 2                143.18                     105.62
# 3                138.96                     115.20
# 4                131.72                     113.13

# %%
df.shape
# Out:
# (511, 7)

# %%
df.columns
# Out:
# Index(['Rank', 'City', 'CostofLivingIndex', 'RentIndex', 'GroceriesIndex',
#        'RestaurantPriceIndex', 'LocalPurchasingPowerIndex'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Rank  CostofLivingIndex   RentIndex  GroceriesIndex  \
# count  511.000000         511.000000  511.000000      511.000000
# mean   256.000000          65.177691   26.765793       63.414697
# std    147.657261          22.371029   17.651107       24.380114
# min      1.000000          21.750000    3.130000       22.030000
# 25%    128.500000          45.740000   12.975000       42.460000
# 50%    256.000000          70.640000   24.540000       64.980000
# 75%    383.500000          79.765000   34.440000       80.460000
# max    511.000000         149.530000  119.630000      163.710000
#
#        RestaurantPriceIndex  LocalPurchasingPowerIndex
# count            511.000000                 511.000000
# mean              58.992524                  79.989687
# std               26.669124                  33.742696
# min               12.120000                   2.960000
# 25%               33.325000                  51.285000
# ...

# %%
df.City.value_counts()
# Out:
# Dar Es Salaam, Tanzania                1
# Limerick, Ireland                      1
# Indore, India                          1
# Chandigarh, India                      1
# Wellington, New Zealand                1
# Noida, India                           1
# Madrid, Spain                          1
# Porto, Portugal                        1
# Dayton, OH, United States              1
# Antwerp, Belgium                       1
# Moncton, Canada                        1
# Hobart, Australia                      1
# Ahmedabad, India                       1
# Haifa, Israel                          1
# Doha, Qatar                            1
# Lethbridge, AB, Canada                 1
# Ann Arbor, MI, United States           1
# Gainesville, FL, United States         1
# Barcelona, Spain                       1
# Allentown, PA, United States           1
# Tampere, Finland                       1
# Algiers, Algeria                       1
# Kitchener, Canada                      1
# ...

# %%
df.rename(columns={"City":"Place"})
# Out:
#      Rank                                  Place  CostofLivingIndex  \
# 0       1                    Zurich, Switzerland             149.53
# 1       2                      Hamilton, Bermuda             148.13
# 2       3                       Zug, Switzerland             142.54
# 3       4                    Geneva, Switzerland             142.12
# 4       5                     Basel, Switzerland             142.02
# 5       6                      Bern, Switzerland             135.51
# 6       7                  Lausanne, Switzerland             131.38
# 7       8                     Reykjavik, Iceland             130.73
# 8       9                    Lugano, Switzerland             124.39
# 9      10                      Stavanger, Norway             116.98
# 10     11                      Trondheim, Norway             116.02
# 11     12                           Oslo, Norway             114.78
# 12     13                         Bergen, Norway             112.66
# ...

# %%
df["Total"]=np.nan
df
# Out:
#      Rank                                   City  CostofLivingIndex  \
# 0       1                    Zurich, Switzerland             149.53
# 1       2                      Hamilton, Bermuda             148.13
# 2       3                       Zug, Switzerland             142.54
# 3       4                    Geneva, Switzerland             142.12
# 4       5                     Basel, Switzerland             142.02
# 5       6                      Bern, Switzerland             135.51
# 6       7                  Lausanne, Switzerland             131.38
# 7       8                     Reykjavik, Iceland             130.73
# 8       9                    Lugano, Switzerland             124.39
# 9      10                      Stavanger, Norway             116.98
# 10     11                      Trondheim, Norway             116.02
# 11     12                           Oslo, Norway             114.78
# 12     13                         Bergen, Norway             112.66
# ...

# %%
df[df["City"]=="Bhubaneswar, India"]
# Out:
#      Rank                City  CostofLivingIndex  RentIndex  GroceriesIndex  \
# 506   507  Bhubaneswar, India              25.24       4.57           28.87
#
#      RestaurantPriceIndex  LocalPurchasingPowerIndex  Total
# 506                 14.71                      52.38    NaN

# %%
df.to_csv("Work.csv")

# %%
del df['Rank']

# %%
df
# Out:
#                                       City  CostofLivingIndex  RentIndex  \
# 0                      Zurich, Switzerland             149.53      66.76
# 1                        Hamilton, Bermuda             148.13     117.80
# 2                         Zug, Switzerland             142.54      67.39
# 3                      Geneva, Switzerland             142.12      70.25
# 4                       Basel, Switzerland             142.02      51.54
# 5                        Bern, Switzerland             135.51      45.33
# 6                    Lausanne, Switzerland             131.38      54.56
# 7                       Reykjavik, Iceland             130.73      55.90
# 8                      Lugano, Switzerland             124.39      51.73
# 9                        Stavanger, Norway             116.98      37.40
# 10                       Trondheim, Norway             116.02      41.27
# 11                            Oslo, Norway             114.78      47.99
# ...

# %%
for c in df.columns:
    print ("---- %s ---" % c)
    print( df[c].value_counts())
# Out:
# ---- City ---
# Dar Es Salaam, Tanzania                1
# Limerick, Ireland                      1
# Indore, India                          1
# Chandigarh, India                      1
# Wellington, New Zealand                1
# Noida, India                           1
# Madrid, Spain                          1
# Porto, Portugal                        1
# Dayton, OH, United States              1
# Antwerp, Belgium                       1
# Moncton, Canada                        1
# Hobart, Australia                      1
# Ahmedabad, India                       1
# Haifa, Israel                          1
# Doha, Qatar                            1
# Lethbridge, AB, Canada                 1
# Ann Arbor, MI, United States           1
# Gainesville, FL, United States         1
# Barcelona, Spain                       1
# Allentown, PA, United States           1
# Tampere, Finland                       1
# Algiers, Algeria                       1
# ...

# %%
df1 = pd.read_csv("Telco-Customer-Churn.csv")

# %%
df1
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
for c in df1.columns:
    print ("---- %s ---" % c)
    print( df1[c].value_counts())
# Out:
# ---- customerID ---
# 6303-KFWSL    1
# 5688-KZTSN    1
# 7181-BQYBV    1
# 2472-OVKUP    1
# 4553-DVPZG    1
# 3976-NLDEZ    1
# 9526-JAWYF    1
# 1337-BOZWO    1
# 5133-VRSAB    1
# 3913-FCUUW    1
# 4647-MUZON    1
# 0461-CVKMU    1
# 0536-ESJEP    1
# 3086-RUCRN    1
# 8780-IXSTS    1
# 5649-ANRML    1
# 8096-LOIST    1
# 8060-HIWJJ    1
# 5176-LMJXE    1
# 6559-ILWKJ    1
# 4654-ULTTN    1
# 5848-FHRFC    1
# 0278-YXOOG    1
# 0442-ZXKVS    1
# 4088-YLDSU    1
# 9970-QBCDA    1
# 1845-CSBRZ    1
# 0078-XZMHT    1
# 0396-YCHWO    1
# 8871-JLMHM    1
#              ..
# 2665-NPTGL    1
# 5732-IKGQH    1
# 0365-GXEZS    1
# 1569-TTNYJ    1
# 3617-XLSGQ    1
# 9588-OZDMQ    1
# 4565-EVZMJ    1
# 1088-CNNKB    1
# 8234-GSZYK    1
# 3898-GUYTS    1
# 8259-DZLIZ    1
# 0541-FITGH    1
# 3466-BYAVD    1
# 7244-KXYZN    1
# 3511-APPBJ    1
# 5868-YTYKS    1
# 9938-ZREHM    1
# 3082-VQXNH    1
# 6178-KFNHS    1
# 6627-CFOSN    1
# 3793-MMFUH    1
# 4804-NCPET    1
# 9029-FEGVJ    1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5785 entries, 0 to 5784
# Data columns (total 21 columns):
# customerID          5785 non-null object
# gender              5785 non-null object
# SeniorCitizen       5785 non-null int64
# Partner             5785 non-null object
# Dependents          5785 non-null object
# tenure              5785 non-null int64
# PhoneService        5785 non-null object
# MultipleLines       5785 non-null object
# InternetService     5785 non-null object
# OnlineSecurity      5785 non-null object
# OnlineBackup        5785 non-null object
# DeviceProtection    5785 non-null object
# TechSupport         5785 non-null object
# StreamingTV         5785 non-null object
# StreamingMovies     5785 non-null object
# Contract            5785 non-null object
# PaperlessBilling    5785 non-null object
# PaymentMethod       5785 non-null object
# MonthlyCharges      5785 non-null float64
# TotalCharges        5785 non-null object
# ...

# %%
df1.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges        Churn
# count    5785.000000  5785.000000     5785.000000  5785.000000
# mean        0.161971    32.263786       64.781011     0.263959
# std         0.368456    24.584428       30.116348     0.440815
# min         0.000000     0.000000       18.250000     0.000000
# 25%         0.000000     9.000000       35.450000     0.000000
# 50%         0.000000    29.000000       70.400000     0.000000
# 75%         0.000000    55.000000       89.850000     1.000000
# max         1.000000    72.000000      118.750000     1.000000

# %%
null = df1.columns[df1.isnull().any()]
df1[null].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
print(df1[df1["TotalCharges"].isnull()][null])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df1[df1.isnull().any(axis=1)][null].head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.isnull("df1")
# Out:
# False

# %%
df1[df1["tenure"]>50]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU    Male              0      No        Yes      62
# 12    8091-TTVAX    Male              0     Yes         No      58
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 17    9959-WOFKT    Male              0      No        Yes      71
# 23    3638-WEABW  Female              0     Yes         No      58
# 28    5248-YGIJN    Male              0     Yes         No      72
# 30    3841-NFECX  Female              1     Yes         No      71
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# 41    9489-DEDVP  Female              0     Yes        Yes      70
# 43    4671-VJLCL  Female              0      No         No      63
# 48    7639-LIAYI    Male              0      No         No      52
# 49    2954-PIBKO  Female              0     Yes        Yes      69
# ...
